# %% [markdown]
# ### Importing the libraries

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# ### Importing the data

# %%
data = pd.read_csv("Salary_Data.csv")
X = data.iloc[:,:-1].values
y = data.iloc[:, -1:].values

# %% [markdown]
# ### Splitting the datasets into training and testing set

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test = train_test_split(X,y,test_size=0.2,random_state=0)

# %% [markdown]
# ### Training the Simple Linear Regression model on training set

# %%
from sklearn.linear_model import LinearRegression
regressor = LinearRegression()
regressor.fit(X_train,y_train)
# Out:
# LinearRegression()

# %% [markdown]
# ### Predicting the test set results

# %%
y_pred = regressor.predict(X_test)

# %% [markdown]
# ### Visualising the Training results

# %%
# x = np.array(np.arange(1,11,0.5))
plt.scatter(X_train,y_train,label="orignal value")
plt.plot(X_train,regressor.predict(X_train),"g",label="Predicted")
plt.title("Training set prediction visualisation")
plt.xlabel("Years of experience")
plt.ylabel("Salary")
plt.legend()
plt.show()

# %% [markdown]
# ### Visualising test set

# %%
plt.scatter(X_test,y_test,label="orignal value")
plt.plot(X_test,regressor.predict(X_test),"g",label="Predicted")
plt.title("Test set prediction visualisation")
plt.xlabel("Years of experience")
plt.ylabel("Salary")
plt.legend()
plt.show()
